# %% [markdown]
# <a href="https://colab.research.google.com/github/emmapraise/Peexoo.Ai-Task/blob/master/Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/tensorflow/models.git
# Out:
# fatal: destination path 'models' already exists and is not an empty directory.

# %%
# !pip install tensorflow-gpu==1.15

# %%
import sys
sys.path.append('/content/models/research/slim')
sys.path.append('/content/models/research')
sys.path.append('/content/models')
print(sys.path)
# Out:
# ['', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions', '/root/.ipython', '/content/models/research/slim', '/content/models/research', '/content/models', '/content/models/research/slim', '/content/models/research', '/content/models']

# %%
# !export PYTHONPATH=$PYTHONPATH:'/content/models':'/content/models'/slim
# !export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim

# %%
# !cp -r '/content/drive/My Drive/images' '/content/models/research/object_detection'
# !cp -r '/content/drive/My Drive/training' '/content/models/research/object_detection'
# !cp '/content/drive/My Drive/xml_to_csv.py' '/content/models/research/object_detection'
# !cp '/content/drive/My Drive/generate_tfrecord.py' '/content/models/research/object_detection'

# %%
import os

path = os.getcwd()

print(path)
# /Users/mbp/Documents/my-project/python-snippets/notebook

os.chdir('/content/models/research')

print(os.getcwd())
# Out:
# /content
# /content/models/research

# %%
# !sudo apt-get install protobuf-compiler python-pil python-lxml python-tk
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# protobuf-compiler is already the newest version (3.0.0-9.1ubuntu1).
# python-lxml is already the newest version (4.2.1-1ubuntu0.1).
# python-pil is already the newest version (5.1.0-1ubuntu0.2).
# python-tk is already the newest version (2.7.17-1~18.04).
# 0 upgraded, 0 newly installed, 0 to remove and 61 not upgraded.

# %%
# !mkdir protoc_3.3
# !cd protoc_3.3/
# !wget wget https://github.com/google/protobuf/releases/download/v3.3.0/protoc-3.3.0-linux-x86_64.zip
# !chmod 775 protoc-3.3.0-linux-x86_64.zip
# !unzip protoc-3.3.0-linux-x86_64.zip
# !/content/models/research/object_detection/protos/*.proto --python_out=.

# %%
# !export PYTHONPATH=$PYTHONPATH:pwd:pwd/slim

# !export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim

# !cp -R slim/ /usr/local/lib/python3.6/dist-packages/object_detection-0.1-py3.6.egg/

# %%
import os
os.environ['PYTHONPATH'] += ':/content/models/research/:/content/models/research/slim/'

# %%
# !protoc object_detection/protos/*.proto --python_out=.

# %%
# !python3.6 setup.py build
# !sudo python3.6 setup.py install
# Out:
# running build
# running build_py
# copying object_detection/generate_tfrecord.py -> build/lib/object_detection
# copying object_detection/train.py -> build/lib/object_detection
# copying object_detection/xml_to_csv.py -> build/lib/object_detection
# copying object_detection/protos/argmax_matcher_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/flexible_grid_anchor_generator_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/string_int_label_map_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/optimizer_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/faster_rcnn_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/image_resizer_pb2.py -> build/lib/object_detection/protos
# copying object_detection/protos/anchor_generator_pb2.py -> build/lib/object_detection/protos
# ...

# %%
os.chdir('/content/models/research/object_detection')

print(os.getcwd())
# Out:
# /content/models/research/object_detection

# %%
# !python generate_tfrecord.py --csv_input=images/test_labels.csv --image_dir=images/test --output_path=test.record
# !python generate_tfrecord.py --csv_input=images/train_labels.csv --image_dir=images/train --output_path=train.record
# Out:
# WARNING:tensorflow:From generate_tfrecord.py:101: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:87: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# W0405 18:38:09.317735 140078931662720 module_wrapper.py:139] From generate_tfrecord.py:87: The name tf.python_io.TFRecordWriter is deprecated. Please use tf.io.TFRecordWriter instead.
#
# WARNING:tensorflow:From generate_tfrecord.py:46: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0405 18:38:09.328140 140078931662720 module_wrapper.py:139] From generate_tfrecord.py:46: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# Successfully created the TFRecords: /content/models/research/object_detection/test.record
# WARNING:tensorflow:From generate_tfrecord.py:101: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# ...

# %%
# !wget http://download.tensorflow.org/models/object_detection/faster_rcnn_inception_v2_coco_2018_01_28.tar.gz
# Out:
# --2020-04-05 18:38:16--  http://download.tensorflow.org/models/object_detection/faster_rcnn_inception_v2_coco_2018_01_28.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 74.125.140.128, 2a00:1450:400c:c08::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|74.125.140.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 149119618 (142M) [application/x-tar]
# Saving to: ‘faster_rcnn_inception_v2_coco_2018_01_28.tar.gz.8’
#
# faster_rcnn_incepti 100%[===================>] 142.21M   123MB/s    in 1.2s
#
# 2020-04-05 18:38:17 (123 MB/s) - ‘faster_rcnn_inception_v2_coco_2018_01_28.tar.gz.8’ saved [149119618/149119618]

# %%
# !tar -xf faster_rcnn_inception_v2_coco_2018_01_28.tar.gz
# !cp '/content/models/research/object_detection/legacy/train.py' '/content/models/research/object_detection'

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs

# !python train.py --logtostderr --train_dir=training --pipeline_config_path=training/faster_rcnn_inception_v2_pets.config
# Out:
# Streaming output truncated to the last 5000 lines.
# I0405 19:05:35.634124 139940175329152 learning.py:507] global step 16919: loss = 0.0033 (0.290 sec/step)
# INFO:tensorflow:global step 16920: loss = 0.0041 (0.294 sec/step)
# I0405 19:05:35.930507 139940175329152 learning.py:507] global step 16920: loss = 0.0041 (0.294 sec/step)
# INFO:tensorflow:global step 16921: loss = 0.0152 (0.293 sec/step)
# I0405 19:05:36.225405 139940175329152 learning.py:507] global step 16921: loss = 0.0152 (0.293 sec/step)
# INFO:tensorflow:global step 16922: loss = 0.0076 (0.296 sec/step)
# I0405 19:05:36.523513 139940175329152 learning.py:507] global step 16922: loss = 0.0076 (0.296 sec/step)
# INFO:tensorflow:global step 16923: loss = 0.0075 (0.294 sec/step)
# I0405 19:05:36.819439 139940175329152 learning.py:507] global step 16923: loss = 0.0075 (0.294 sec/step)
# INFO:tensorflow:global step 16924: loss = 0.0250 (0.290 sec/step)
# ...

# %%
# !tensorboard --logdir=training
# Out:
# W0405 19:18:17.992203 140364003272448 plugin_event_accumulator.py:294] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# W0405 19:18:18.003033 140364003272448 plugin_event_accumulator.py:302] Found more than one metagraph event per run. Overwriting the metagraph with the newest event.
# W0405 19:18:18.007575 140364003272448 plugin_event_accumulator.py:556] Detected out of order event.step likely caused by a TensorFlow restart. Purging 366 expired tensor events from Tensorboard display between the previous step: 0 (timestamp: 1586104993.2803016) and current step: 0 (timestamp: 1586107360.1398482).
# W0405 19:18:19.167073 140364003272448 plugin_event_accumulator.py:294] Found more than one graph event per run, or there was a metagraph containing a graph_def, as well as one or more graph events.  Overwriting the graph with the newest event.
# ...

# %%
# !python export_inference_graph.py --input_type image_tensor --pipeline_config_path training/faster_rcnn_inception_v2_pets.config --trained_checkpoint_prefix training/model.ckpt-17574 --output_directory inference_graph
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From export_inference_graph.py:162: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# WARNING:tensorflow:From export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# W0405 19:25:29.896751 140133889374080 module_wrapper.py:139] From export_inference_graph.py:145: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.
#
# ...
